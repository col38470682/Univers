# %% [markdown]
# # GVH Jovian Temporal Comparison 2000–2026 0.1
#
# Notebook dédié à la comparaison temporelle.
#
# ## Structure
# 1. Chargement des CSV uniquement
# 2. Fusion 2000 / 2013 / 2026
# 3. Comparaison des observables
# 4. Variations relatives
# 5. Analyse de stabilité
# 6. Figures
# 7. Exports

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## À compléter
