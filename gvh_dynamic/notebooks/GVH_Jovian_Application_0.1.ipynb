# %% [markdown]
# # GVH Jovian Application 0.1
#
# Pipeline d'application GVH aux satellites galiléens.
#
# ## Structure
# 1. Chargement des données JPL Horizons
# 2. Construction des transitions
# 3. Calcul des observables GVH
# 4. Observables angulaires
# 5. Exports CSV

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## À compléter
